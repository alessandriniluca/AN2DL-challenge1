# %% [markdown]
# This is the first net we used to classify Tomatoes and Others (all the others leaves)

# %%
# mount gdrive

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/Challenge1_Mio/only_tomato_CNN/
# Out:
# /gdrive/MyDrive/Challenge1_Mio/only_tomato_CNN

# %%
# Unzip the folder containing the dataset, divided in training - validation and test
# We have just two classes - Tomatoes and Others
# !unzip only_tomato.zip
# Out:
# Output streaming troncato alle ultime 5000 righe.
#   inflating: only_tomato/train/Tomato/42653.jpg
#   inflating: only_tomato/train/Tomato/38640.jpg
#   inflating: only_tomato/train/Tomato/39219.jpg
#   inflating: only_tomato/train/Tomato/41120.jpg
#   inflating: only_tomato/train/Tomato/41564.jpg
#   inflating: only_tomato/train/Tomato/40160.jpg
#   inflating: only_tomato/train/Tomato/42811.jpg
#   inflating: only_tomato/train/Tomato/40907.jpg
#   inflating: only_tomato/train/Tomato/39684.jpg
#   inflating: only_tomato/train/Tomato/43993.jpg
#   inflating: only_tomato/train/Tomato/42089.jpg
#   inflating: only_tomato/train/Tomato/38356.jpg
#   inflating: only_tomato/train/Tomato/21344.jpg
#   inflating: only_tomato/train/Tomato/38164.jpg
#   inflating: only_tomato/train/Tomato/43943.jpg
#   inflating: only_tomato/train/Tomato/38513.jpg
#   inflating: only_tomato/train/Tomato/39466.jpg
#   inflating: only_tomato/train/Tomato/43731.jpg
#   inflating: only_tomato/train/Tomato/21439.jpg
#   inflating: only_tomato/train/Tomato/39046.jpg
#   inflating: only_tomato/train/Tomato/39027.jpg
#   inflating: only_tomato/train/Tomato/41223.jpg
#   inflating: only_tomato/train/Tomato/43722.jpg
#   inflating: only_tomato/train/Tomato/37805.jpg
#   inflating: only_tomato/train/Tomato/42518.jpg
#   inflating: only_tomato/train/Tomato/39139.jpg
#   inflating: only_tomato/train/Tomato/20947.jpg
#   inflating: only_tomato/train/Tomato/39475.jpg
#   inflating: only_tomato/train/Tomato/39229.jpg
#   inflating: only_tomato/train/Tomato/39714.jpg
#   inflating: only_tomato/train/Tomato/42525.jpg
#   inflating: only_tomato/train/Tomato/42278.jpg
#   inflating: only_tomato/train/Tomato/41797.jpg
#   inflating: only_tomato/train/Tomato/38161.jpg
#   inflating: only_tomato/train/Tomato/37884.jpg
#   inflating: only_tomato/train/Tomato/41583.jpg
#   inflating: only_tomato/train/Tomato/39906.jpg
#   inflating: only_tomato/train/Tomato/39995.jpg
#   inflating: only_tomato/train/Tomato/39807.jpg
#   inflating: only_tomato/train/Tomato/41359.jpg
#   inflating: only_tomato/train/Tomato/38227.jpg
#   inflating: only_tomato/train/Tomato/43625.jpg
#   inflating: only_tomato/train/Tomato/39232.jpg
#   inflating: only_tomato/train/Tomato/37900.jpg
#   inflating: only_tomato/train/Tomato/39560.jpg
#   inflating: only_tomato/train/Tomato/40257.jpg
#   inflating: only_tomato/train/Tomato/43780.jpg
#   inflating: only_tomato/train/Tomato/42808.jpg
#   inflating: only_tomato/train/Tomato/43400.jpg
#   inflating: only_tomato/train/Tomato/40663.jpg
#   inflating: only_tomato/train/Tomato/38792.jpg
#   inflating: only_tomato/train/Tomato/40965.jpg
#   inflating: only_tomato/train/Tomato/20869.jpg
#   inflating: only_tomato/train/Tomato/41231.jpg
#   inflating: only_tomato/train/Tomato/39161.jpg
#   inflating: only_tomato/train/Tomato/41472.jpg
#   inflating: only_tomato/train/Tomato/43891.jpg
#   inflating: only_tomato/train/Tomato/20907.jpg
#   inflating: only_tomato/train/Tomato/40857.jpg
#   inflating: only_tomato/train/Tomato/21403.jpg
#   inflating: only_tomato/train/Tomato/39507.jpg
#   inflating: only_tomato/train/Tomato/42625.jpg
#   inflating: only_tomato/train/Tomato/43820.jpg
#   inflating: only_tomato/train/Tomato/43502.jpg
#   inflating: only_tomato/train/Tomato/40394.jpg
#   inflating: only_tomato/train/Tomato/41332.jpg
#   inflating: only_tomato/train/Tomato/21017.jpg
#   inflating: only_tomato/train/Tomato/38011.jpg
#   inflating: only_tomato/train/Tomato/21022.jpg
#   inflating: only_tomato/train/Tomato/40893.jpg
#   inflating: only_tomato/train/Tomato/42775.jpg
#   inflating: only_tomato/train/Tomato/42748.jpg
#   inflating: only_tomato/train/Tomato/43448.jpg
#   inflating: only_tomato/train/Tomato/39218.jpg
#   inflating: only_tomato/train/Tomato/43868.jpg
#   inflating: only_tomato/train/Tomato/40380.jpg
#   inflating: only_tomato/train/Tomato/43827.jpg
#   inflating: only_tomato/train/Tomato/40264.jpg
#   inflating: only_tomato/train/Tomato/42209.jpg
#   inflating: only_tomato/train/Tomato/39567.jpg
#   inflating: only_tomato/train/Tomato/42111.jpg
#   inflating: only_tomato/train/Tomato/39374.jpg
#   inflating: only_tomato/train/Tomato/37864.jpg
#   inflating: only_tomato/train/Tomato/42043.jpg
#   inflating: only_tomato/train/Tomato/42356.jpg
#   inflating: only_tomato/train/Tomato/42846.jpg
#   inflating: only_tomato/train/Tomato/39615.jpg
#   inflating: only_tomato/train/Tomato/42532.jpg
#   inflating: only_tomato/train/Tomato/40403.jpg
#   inflating: only_tomato/train/Tomato/42537.jpg
#   inflating: only_tomato/train/Tomato/39461.jpg
#   inflating: only_tomato/train/Tomato/43322.jpg
#   inflating: only_tomato/train/Tomato/37817.jpg
#   inflating: only_tomato/train/Tomato/39524.jpg
#   inflating: only_tomato/train/Tomato/39205.jpg
#   inflating: only_tomato/train/Tomato/40650.jpg
#   inflating: only_tomato/train/Tomato/37892.jpg
#   inflating: only_tomato/train/Tomato/39248.jpg
#   inflating: only_tomato/train/Tomato/40039.jpg
#   inflating: only_tomato/train/Tomato/43302.jpg
#   inflating: only_tomato/train/Tomato/42881.jpg
#   inflating: only_tomato/train/Tomato/42848.jpg
#   inflating: only_tomato/train/Tomato/40282.jpg
#   inflating: only_tomato/train/Tomato/43873.jpg
#   inflating: only_tomato/train/Tomato/40065.jpg
#   inflating: only_tomato/train/Tomato/44047.jpg
#   inflating: only_tomato/train/Tomato/43844.jpg
#   inflating: only_tomato/train/Tomato/44229.jpg
#   inflating: only_tomato/train/Tomato/43254.jpg
#   inflating: only_tomato/train/Tomato/42046.jpg
#   inflating: only_tomato/train/Tomato/39760.jpg
#   inflating: only_tomato/train/Tomato/39536.jpg
#   inflating: only_tomato/train/Tomato/43289.jpg
#   inflating: only_tomato/train/Tomato/38982.jpg
#   inflating: only_tomato/train/Tomato/39018.jpg
#   inflating: only_tomato/train/Tomato/40232.jpg
#   inflating: only_tomato/train/Tomato/41701.jpg
#   inflating: only_tomato/train/Tomato/41017.jpg
#   inflating: only_tomato/train/Tomato/39416.jpg
#   inflating: only_tomato/train/Tomato/43674.jpg
#   inflating: only_tomato/train/Tomato/21206.jpg
#   inflating: only_tomato/train/Tomato/43760.jpg
#   inflating: only_tomato/train/Tomato/43988.jpg
#   inflating: only_tomato/train/Tomato/21083.jpg
#   inflating: only_tomato/train/Tomato/38211.jpg
#   inflating: only_tomato/train/Tomato/38336.jpg
#   inflating: only_tomato/train/Tomato/39736.jpg
#   inflating: only_tomato/train/Tomato/39659.jpg
#   inflating: only_tomato/train/Tomato/41904.jpg
#   inflating: only_tomato/train/Tomato/40066.jpg
#   inflating: only_tomato/train/Tomato/43380.jpg
#   inflating: only_tomato/train/Tomato/38372.jpg
#   inflating: only_tomato/train/Tomato/38463.jpg
#   inflating: only_tomato/train/Tomato/37743.jpg
#   inflating: only_tomato/train/Tomato/21368.jpg
#   inflating: only_tomato/train/Tomato/41878.jpg
#   inflating: only_tomato/train/Tomato/39737.jpg
#   inflating: only_tomato/train/Tomato/41530.jpg
#   inflating: only_tomato/train/Tomato/42908.jpg
#   inflating: only_tomato/train/Tomato/38701.jpg
#   inflating: only_tomato/train/Tomato/40207.jpg
#   inflating: only_tomato/train/Tomato/38853.jpg
#   inflating: only_tomato/train/Tomato/39593.jpg
#   inflating: only_tomato/train/Tomato/21136.jpg
#   inflating: only_tomato/train/Tomato/38628.jpg
#   inflating: only_tomato/train/Tomato/40616.jpg
#   inflating: only_tomato/train/Tomato/20990.jpg
#   inflating: only_tomato/train/Tomato/40036.jpg
#   inflating: only_tomato/train/Tomato/38449.jpg
#   inflating: only_tomato/train/Tomato/21243.jpg
#   inflating: only_tomato/train/Tomato/40256.jpg
#   inflating: only_tomato/train/Tomato/38382.jpg
#   inflating: only_tomato/train/Tomato/37946.jpg
#   inflating: only_tomato/train/Tomato/37899.jpg
#   inflating: only_tomato/train/Tomato/37751.jpg
#   inflating: only_tomato/train/Tomato/41373.jpg
#   inflating: only_tomato/train/Tomato/41034.jpg
#   inflating: only_tomato/train/Tomato/40388.jpg
#   inflating: only_tomato/train/Tomato/39926.jpg
#   inflating: only_tomato/train/Tomato/38878.jpg
#   inflating: only_tomato/train/Tomato/42282.jpg
#   inflating: only_tomato/train/Tomato/37757.jpg
#   inflating: only_tomato/train/Tomato/21208.jpg
#   inflating: only_tomato/train/Tomato/43069.jpg
#   inflating: only_tomato/train/Tomato/39202.jpg
#   inflating: only_tomato/train/Tomato/41041.jpg
#   inflating: only_tomato/train/Tomato/43710.jpg
#   inflating: only_tomato/train/Tomato/39927.jpg
#   inflating: only_tomato/train/Tomato/41221.jpg
#   inflating: only_tomato/train/Tomato/42121.jpg
#   inflating: only_tomato/train/Tomato/39640.jpg
#   inflating: only_tomato/train/Tomato/38318.jpg
#   inflating: only_tomato/train/Tomato/37739.jpg
#   inflating: only_tomato/train/Tomato/42472.jpg
#   inflating: only_tomato/train/Tomato/43157.jpg
#   inflating: only_tomato/train/Tomato/21273.jpg
#   inflating: only_tomato/train/Tomato/42960.jpg
#   inflating: only_tomato/train/Tomato/43323.jpg
#   inflating: only_tomato/train/Tomato/41824.jpg
#   inflating: only_tomato/train/Tomato/40668.jpg
#   inflating: only_tomato/train/Tomato/39096.jpg
#   inflating: only_tomato/train/Tomato/39752.jpg
#   inflating: only_tomato/train/Tomato/43718.jpg
#   inflating: only_tomato/train/Tomato/42287.jpg
#   inflating: only_tomato/train/Tomato/20966.jpg
#   inflating: only_tomato/train/Tomato/38526.jpg
#   inflating: only_tomato/train/Tomato/39815.jpg
#   inflating: only_tomato/train/Tomato/43600.jpg
#   inflating: only_tomato/train/Tomato/21220.jpg
#   inflating: only_tomato/train/Tomato/39011.jpg
#   inflating: only_tomato/train/Tomato/40013.jpg
#   inflating: only_tomato/train/Tomato/21170.jpg
#   inflating: only_tomato/train/Tomato/21010.jpg
#   inflating: only_tomato/train/Tomato/40586.jpg
#   inflating: only_tomato/train/Tomato/40540.jpg
#   inflating: only_tomato/train/Tomato/43500.jpg
#   inflating: only_tomato/train/Tomato/42512.jpg
#   inflating: only_tomato/train/Tomato/40646.jpg
#   inflating: only_tomato/train/Tomato/38670.jpg
#   inflating: only_tomato/train/Tomato/38784.jpg
#   inflating: only_tomato/train/Tomato/38743.jpg
#   inflating: only_tomato/train/Tomato/44194.jpg
#   inflating: only_tomato/train/Tomato/21230.jpg
#   inflating: only_tomato/train/Tomato/39275.jpg
#   inflating: only_tomato/train/Tomato/42189.jpg
#   inflating: only_tomato/train/Tomato/39759.jpg
#   inflating: only_tomato/train/Tomato/41863.jpg
#   inflating: only_tomato/train/Tomato/38991.jpg
#   inflating: only_tomato/train/Tomato/39656.jpg
#   inflating: only_tomato/train/Tomato/40656.jpg
#   inflating: only_tomato/train/Tomato/38847.jpg
#   inflating: only_tomato/train/Tomato/39092.jpg
#   inflating: only_tomato/train/Tomato/41688.jpg
#   inflating: only_tomato/train/Tomato/38568.jpg
#   inflating: only_tomato/train/Tomato/38087.jpg
#   inflating: only_tomato/train/Tomato/42395.jpg
#   inflating: only_tomato/train/Tomato/41909.jpg
#   inflating: only_tomato/train/Tomato/38607.jpg
#   inflating: only_tomato/train/Tomato/43962.jpg
#   inflating: only_tomato/train/Tomato/41094.jpg
#   inflating: only_tomato/train/Tomato/41269.jpg
#   inflating: only_tomato/train/Tomato/38917.jpg
#   inflating: only_tomato/train/Tomato/37794.jpg
#   inflating: only_tomato/train/Tomato/38808.jpg
#   inflating: only_tomato/train/Tomato/40980.jpg
#   inflating: only_tomato/train/Tomato/38880.jpg
#   inflating: only_tomato/train/Tomato/21171.jpg
#   inflating: only_tomato/train/Tomato/42858.jpg
#   inflating: only_tomato/train/Tomato/40937.jpg
#   inflating: only_tomato/train/Tomato/42695.jpg
#   inflating: only_tomato/train/Tomato/39094.jpg
#   inflating: only_tomato/train/Tomato/43634.jpg
#   inflating: only_tomato/train/Tomato/39703.jpg
#   inflating: only_tomato/train/Tomato/39701.jpg
#   inflating: only_tomato/train/Tomato/43866.jpg
#   inflating: only_tomato/train/Tomato/39783.jpg
#   inflating: only_tomato/train/Tomato/39235.jpg
#   inflating: only_tomato/train/Tomato/38920.jpg
#   inflating: only_tomato/train/Tomato/39301.jpg
#   inflating: only_tomato/train/Tomato/38598.jpg
#   inflating: only_tomato/train/Tomato/39738.jpg
#   inflating: only_tomato/train/Tomato/39848.jpg
#   inflating: only_tomato/train/Tomato/44046.jpg
#   inflating: only_tomato/train/Tomato/39666.jpg
#   inflating: only_tomato/train/Tomato/43961.jpg
#   inflating: only_tomato/train/Tomato/21079.jpg
#   inflating: only_tomato/train/Tomato/38644.jpg
#   inflating: only_tomato/train/Tomato/43419.jpg
#   inflating: only_tomato/train/Tomato/41774.jpg
#   inflating: only_tomato/train/Tomato/42596.jpg
#   inflating: only_tomato/train/Tomato/44130.jpg
#   inflating: only_tomato/train/Tomato/40773.jpg
#   inflating: only_tomato/train/Tomato/39141.jpg
#   inflating: only_tomato/train/Tomato/20970.jpg
#   inflating: only_tomato/train/Tomato/43745.jpg
#   inflating: only_tomato/train/Tomato/41660.jpg
#   inflating: only_tomato/train/Tomato/43076.jpg
#   inflating: only_tomato/train/Tomato/41737.jpg
#   inflating: only_tomato/train/Tomato/40910.jpg
#   inflating: only_tomato/train/Tomato/43777.jpg
#   inflating: only_tomato/train/Tomato/43510.jpg
#   inflating: only_tomato/train/Tomato/43801.jpg
#   inflating: only_tomato/train/Tomato/41683.jpg
#   inflating: only_tomato/train/Tomato/42609.jpg
#   inflating: only_tomato/train/Tomato/40964.jpg
#   inflating: only_tomato/train/Tomato/21215.jpg
#   inflating: only_tomato/train/Tomato/42864.jpg
#   inflating: only_tomato/train/Tomato/37908.jpg
#   inflating: only_tomato/train/Tomato/40607.jpg
#   inflating: only_tomato/train/Tomato/39296.jpg
#   inflating: only_tomato/train/Tomato/38954.jpg
#   inflating: only_tomato/train/Tomato/42470.jpg
#   inflating: only_tomato/train/Tomato/43574.jpg
#   inflating: only_tomato/train/Tomato/40469.jpg
#   inflating: only_tomato/train/Tomato/43583.jpg
#   inflating: only_tomato/train/Tomato/41119.jpg
#   inflating: only_tomato/train/Tomato/42460.jpg
#   inflating: only_tomato/train/Tomato/43075.jpg
#   inflating: only_tomato/train/Tomato/38641.jpg
#   inflating: only_tomato/train/Tomato/42305.jpg
#   inflating: only_tomato/train/Tomato/39039.jpg
#   inflating: only_tomato/train/Tomato/42685.jpg
#   inflating: only_tomato/train/Tomato/41932.jpg
#   inflating: only_tomato/train/Tomato/37810.jpg
#   inflating: only_tomato/train/Tomato/38647.jpg
#   inflating: only_tomato/train/Tomato/40419.jpg
#   inflating: only_tomato/train/Tomato/43909.jpg
#   inflating: only_tomato/train/Tomato/39134.jpg
#   inflating: only_tomato/train/Tomato/38605.jpg
#   inflating: only_tomato/train/Tomato/38617.jpg
#   inflating: only_tomato/train/Tomato/38831.jpg
#   inflating: only_tomato/train/Tomato/40817.jpg
#   inflating: only_tomato/train/Tomato/40600.jpg
#   inflating: only_tomato/train/Tomato/43174.jpg
#   inflating: only_tomato/train/Tomato/39695.jpg
#   inflating: only_tomato/train/Tomato/38535.jpg
#   inflating: only_tomato/train/Tomato/42013.jpg
#   inflating: only_tomato/train/Tomato/41979.jpg
#   inflating: only_tomato/train/Tomato/41915.jpg
#   inflating: only_tomato/train/Tomato/21130.jpg
#   inflating: only_tomato/train/Tomato/43705.jpg
#   inflating: only_tomato/train/Tomato/43757.jpg
#   inflating: only_tomato/train/Tomato/39876.jpg
#   inflating: only_tomato/train/Tomato/39792.jpg
#   inflating: only_tomato/train/Tomato/43901.jpg
#   inflating: only_tomato/train/Tomato/43194.jpg
#   inflating: only_tomato/train/Tomato/39724.jpg
#   inflating: only_tomato/train/Tomato/38759.jpg
#   inflating: only_tomato/train/Tomato/40779.jpg
#   inflating: only_tomato/train/Tomato/38039.jpg
#   inflating: only_tomato/train/Tomato/38787.jpg
#   inflating: only_tomato/train/Tomato/43141.jpg
#   inflating: only_tomato/train/Tomato/41340.jpg
#   inflating: only_tomato/train/Tomato/42640.jpg
#   inflating: only_tomato/train/Tomato/38077.jpg
#   inflating: only_tomato/train/Tomato/21297.jpg
#   inflating: only_tomato/train/Tomato/43085.jpg
#   inflating: only_tomato/train/Tomato/20860.jpg
#   inflating: only_tomato/train/Tomato/43095.jpg
#   inflating: only_tomato/train/Tomato/37877.jpg
#   inflating: only_tomato/train/Tomato/38830.jpg
#   inflating: only_tomato/train/Tomato/41015.jpg
#   inflating: only_tomato/train/Tomato/42513.jpg
#   inflating: only_tomato/train/Tomato/43582.jpg
#   inflating: only_tomato/train/Tomato/38634.jpg
#   inflating: only_tomato/train/Tomato/21184.jpg
#   inflating: only_tomato/train/Tomato/43122.jpg
#   inflating: only_tomato/train/Tomato/40182.jpg
#   inflating: only_tomato/train/Tomato/21218.jpg
#   inflating: only_tomato/train/Tomato/41133.jpg
#   inflating: only_tomato/train/Tomato/38304.jpg
#   inflating: only_tomato/train/Tomato/21199.jpg
#   inflating: only_tomato/train/Tomato/38267.jpg
#   inflating: only_tomato/train/Tomato/21323.jpg
#   inflating: only_tomato/train/Tomato/20930.jpg
#   inflating: only_tomato/train/Tomato/41505.jpg
#   inflating: only_tomato/train/Tomato/40972.jpg
#   inflating: only_tomato/train/Tomato/41764.jpg
#   inflating: only_tomato/train/Tomato/43175.jpg
#   inflating: only_tomato/train/Tomato/38819.jpg
#   inflating: only_tomato/train/Tomato/42030.jpg
#   inflating: only_tomato/train/Tomato/20919.jpg
#   inflating: only_tomato/train/Tomato/38398.jpg
#   inflating: only_tomato/train/Tomato/43814.jpg
#   inflating: only_tomato/train/Tomato/38651.jpg
#   inflating: only_tomato/train/Tomato/39338.jpg
#   inflating: only_tomato/train/Tomato/42621.jpg
#   inflating: only_tomato/train/Tomato/41318.jpg
#   inflating: only_tomato/train/Tomato/42384.jpg
#   inflating: only_tomato/train/Tomato/41421.jpg
#   inflating: only_tomato/train/Tomato/43853.jpg
#   inflating: only_tomato/train/Tomato/44209.jpg
#   inflating: only_tomato/train/Tomato/21058.jpg
#   inflating: only_tomato/train/Tomato/43934.jpg
#   inflating: only_tomato/train/Tomato/42401.jpg
#   inflating: only_tomato/train/Tomato/43013.jpg
#   inflating: only_tomato/train/Tomato/39949.jpg
#   inflating: only_tomato/train/Tomato/38860.jpg
#   inflating: only_tomato/train/Tomato/42358.jpg
#   inflating: only_tomato/train/Tomato/39035.jpg
#   inflating: only_tomato/train/Tomato/44164.jpg
#   inflating: only_tomato/train/Tomato/38517.jpg
#   inflating: only_tomato/train/Tomato/40762.jpg
#   inflating: only_tomato/train/Tomato/40617.jpg
#   inflating: only_tomato/train/Tomato/21166.jpg
#   inflating: only_tomato/train/Tomato/43241.jpg
#   inflating: only_tomato/train/Tomato/21419.jpg
#   inflating: only_tomato/train/Tomato/43981.jpg
#   inflating: only_tomato/train/Tomato/39909.jpg
#   inflating: only_tomato/train/Tomato/40966.jpg
#   inflating: only_tomato/train/Tomato/38375.jpg
#   inflating: only_tomato/train/Tomato/43685.jpg
#   inflating: only_tomato/train/Tomato/37768.jpg
#   inflating: only_tomato/train/Tomato/38645.jpg
#   inflating: only_tomato/train/Tomato/42614.jpg
#   inflating: only_tomato/train/Tomato/41893.jpg
#   inflating: only_tomato/train/Tomato/38091.jpg
#   inflating: only_tomato/train/Tomato/42101.jpg
#   inflating: only_tomato/train/Tomato/42440.jpg
#   inflating: only_tomato/train/Tomato/39287.jpg
#   inflating: only_tomato/train/Tomato/44119.jpg
#   inflating: only_tomato/train/Tomato/39605.jpg
#   inflating: only_tomato/train/Tomato/40308.jpg
#   inflating: only_tomato/train/Tomato/39590.jpg
#   inflating: only_tomato/train/Tomato/41944.jpg
#   inflating: only_tomato/train/Tomato/40366.jpg
#   inflating: only_tomato/train/Tomato/21365.jpg
#   inflating: only_tomato/train/Tomato/39140.jpg
#   inflating: only_tomato/train/Tomato/42059.jpg
#   inflating: only_tomato/train/Tomato/43256.jpg
#   inflating: only_tomato/train/Tomato/42208.jpg
#   inflating: only_tomato/train/Tomato/41116.jpg
#   inflating: only_tomato/train/Tomato/42129.jpg
#   inflating: only_tomato/train/Tomato/38224.jpg
#   inflating: only_tomato/train/Tomato/40511.jpg
#   inflating: only_tomato/train/Tomato/42499.jpg
#   inflating: only_tomato/train/Tomato/38182.jpg
#   inflating: only_tomato/train/Tomato/38434.jpg
#   inflating: only_tomato/train/Tomato/40117.jpg
#   inflating: only_tomato/train/Tomato/38296.jpg
#   inflating: only_tomato/train/Tomato/41449.jpg
#   inflating: only_tomato/train/Tomato/41135.jpg
#   inflating: only_tomato/train/Tomato/39766.jpg
#   inflating: only_tomato/train/Tomato/41126.jpg
#   inflating: only_tomato/train/Tomato/41515.jpg
#   inflating: only_tomato/train/Tomato/39699.jpg
#   inflating: only_tomato/train/Tomato/41236.jpg
#   inflating: only_tomato/train/Tomato/39607.jpg
#   inflating: only_tomato/train/Tomato/43519.jpg
#   inflating: only_tomato/train/Tomato/38734.jpg
#   inflating: only_tomato/train/Tomato/38000.jpg
#   inflating: only_tomato/train/Tomato/38111.jpg
#   inflating: only_tomato/train/Tomato/40847.jpg
#   inflating: only_tomato/train/Tomato/21175.jpg
#   inflating: only_tomato/train/Tomato/40357.jpg
#   inflating: only_tomato/train/Tomato/39328.jpg
#   inflating: only_tomato/train/Tomato/44018.jpg
#   inflating: only_tomato/train/Tomato/39523.jpg
#   inflating: only_tomato/train/Tomato/38030.jpg
#   inflating: only_tomato/train/Tomato/40870.jpg
#   inflating: only_tomato/train/Tomato/42999.jpg
#   inflating: only_tomato/train/Tomato/40655.jpg
#   inflating: only_tomato/train/Tomato/38606.jpg
#   inflating: only_tomato/train/Tomato/41382.jpg
#   inflating: only_tomato/train/Tomato/42119.jpg
#   inflating: only_tomato/train/Tomato/39228.jpg
#   inflating: only_tomato/train/Tomato/42505.jpg
#   inflating: only_tomato/train/Tomato/41519.jpg
#   inflating: only_tomato/train/Tomato/43528.jpg
#   inflating: only_tomato/train/Tomato/40467.jpg
#   inflating: only_tomato/train/Tomato/20957.jpg
#   inflating: only_tomato/train/Tomato/40426.jpg
#   inflating: only_tomato/train/Tomato/38548.jpg
#   inflating: only_tomato/train/Tomato/43312.jpg
#   inflating: only_tomato/train/Tomato/43991.jpg
#   inflating: only_tomato/train/Tomato/43169.jpg
#   inflating: only_tomato/train/Tomato/42507.jpg
#   inflating: only_tomato/train/Tomato/21062.jpg
#   inflating: only_tomato/train/Tomato/43751.jpg
#   inflating: only_tomato/train/Tomato/43475.jpg
#   inflating: only_tomato/train/Tomato/38423.jpg
#   inflating: only_tomato/train/Tomato/38888.jpg
#   inflating: only_tomato/train/Tomato/41265.jpg
#   inflating: only_tomato/train/Tomato/44215.jpg
#   inflating: only_tomato/train/Tomato/42975.jpg
#   inflating: only_tomato/train/Tomato/42194.jpg
#   inflating: only_tomato/train/Tomato/41027.jpg
#   inflating: only_tomato/train/Tomato/20877.jpg
#   inflating: only_tomato/train/Tomato/40604.jpg
#   inflating: only_tomato/train/Tomato/21248.jpg
#   inflating: only_tomato/train/Tomato/42324.jpg
#   inflating: only_tomato/train/Tomato/39444.jpg
#   inflating: only_tomato/train/Tomato/39597.jpg
#   inflating: only_tomato/train/Tomato/42498.jpg
#   inflating: only_tomato/train/Tomato/39170.jpg
#   inflating: only_tomato/train/Tomato/39222.jpg
#   inflating: only_tomato/train/Tomato/39124.jpg
#   inflating: only_tomato/train/Tomato/43458.jpg
#   inflating: only_tomato/train/Tomato/42698.jpg
#   inflating: only_tomato/train/Tomato/42838.jpg
#   inflating: only_tomato/train/Tomato/39647.jpg
#   inflating: only_tomato/train/Tomato/43350.jpg
#   inflating: only_tomato/train/Tomato/39102.jpg
#   inflating: only_tomato/train/Tomato/38869.jpg
#   inflating: only_tomato/train/Tomato/39669.jpg
#   inflating: only_tomato/train/Tomato/41111.jpg
#   inflating: only_tomato/train/Tomato/39244.jpg
#   inflating: only_tomato/train/Tomato/39698.jpg
#   inflating: only_tomato/train/Tomato/40087.jpg
#   inflating: only_tomato/train/Tomato/44044.jpg
#   inflating: only_tomato/train/Tomato/42959.jpg
#   inflating: only_tomato/train/Tomato/41550.jpg
#   inflating: only_tomato/train/Tomato/42955.jpg
#   inflating: only_tomato/train/Tomato/38884.jpg
#   inflating: only_tomato/train/Tomato/43100.jpg
#   inflating: only_tomato/train/Tomato/42170.jpg
#   inflating: only_tomato/train/Tomato/42451.jpg
#   inflating: only_tomato/train/Tomato/38462.jpg
#   inflating: only_tomato/train/Tomato/39827.jpg
#   inflating: only_tomato/train/Tomato/42780.jpg
#   inflating: only_tomato/train/Tomato/38360.jpg
#   inflating: only_tomato/train/Tomato/38795.jpg
#   inflating: only_tomato/train/Tomato/41128.jpg
#   inflating: only_tomato/train/Tomato/21070.jpg
#   inflating: only_tomato/train/Tomato/43654.jpg
#   inflating: only_tomato/train/Tomato/44078.jpg
#   inflating: only_tomato/train/Tomato/42490.jpg
#   inflating: only_tomato/train/Tomato/40738.jpg
#   inflating: only_tomato/train/Tomato/44182.jpg
#   inflating: only_tomato/train/Tomato/37881.jpg
#   inflating: only_tomato/train/Tomato/42603.jpg
#   inflating: only_tomato/train/Tomato/43793.jpg
#   inflating: only_tomato/train/Tomato/20951.jpg
#   inflating: only_tomato/train/Tomato/42366.jpg
#   inflating: only_tomato/train/Tomato/38026.jpg
#   inflating: only_tomato/train/Tomato/39034.jpg
#   inflating: only_tomato/train/Tomato/38032.jpg
#   inflating: only_tomato/train/Tomato/40938.jpg
#   inflating: only_tomato/train/Tomato/42156.jpg
#   inflating: only_tomato/train/Tomato/38798.jpg
#   inflating: only_tomato/train/Tomato/38494.jpg
#   inflating: only_tomato/train/Tomato/39435.jpg
#   inflating: only_tomato/train/Tomato/43127.jpg
#   inflating: only_tomato/train/Tomato/43586.jpg
#   inflating: only_tomato/train/Tomato/40814.jpg
#   inflating: only_tomato/train/Tomato/42398.jpg
#   inflating: only_tomato/train/Tomato/40447.jpg
#   inflating: only_tomato/train/Tomato/40416.jpg
#   inflating: only_tomato/train/Tomato/40903.jpg
#   inflating: only_tomato/train/Tomato/39861.jpg
#   inflating: only_tomato/train/Tomato/43645.jpg
#   inflating: only_tomato/train/Tomato/40042.jpg
#   inflating: only_tomato/train/Tomato/38575.jpg
#   inflating: only_tomato/train/Tomato/40724.jpg
#   inflating: only_tomato/train/Tomato/39127.jpg
#   inflating: only_tomato/train/Tomato/43160.jpg
#   inflating: only_tomato/train/Tomato/39709.jpg
#   inflating: only_tomato/train/Tomato/38126.jpg
#   inflating: only_tomato/train/Tomato/43033.jpg
#   inflating: only_tomato/train/Tomato/42556.jpg
#   inflating: only_tomato/train/Tomato/38966.jpg
#   inflating: only_tomato/train/Tomato/42200.jpg
#   inflating: only_tomato/train/Tomato/43345.jpg
#   inflating: only_tomato/train/Tomato/43195.jpg
#   inflating: only_tomato/train/Tomato/38649.jpg
#   inflating: only_tomato/train/Tomato/38190.jpg
#   inflating: only_tomato/train/Tomato/38754.jpg
#   inflating: only_tomato/train/Tomato/38659.jpg
#   inflating: only_tomato/train/Tomato/39415.jpg
#   inflating: only_tomato/train/Tomato/40400.jpg
#   inflating: only_tomato/train/Tomato/40759.jpg
#   inflating: only_tomato/train/Tomato/41695.jpg
#   inflating: only_tomato/train/Tomato/41071.jpg
#   inflating: only_tomato/train/Tomato/39981.jpg
#   inflating: only_tomato/train/Tomato/42474.jpg
#   inflating: only_tomato/train/Tomato/43915.jpg
#   inflating: only_tomato/train/Tomato/41090.jpg
#   inflating: only_tomato/train/Tomato/43125.jpg
#   inflating: only_tomato/train/Tomato/40490.jpg
#   inflating: only_tomato/train/Tomato/42542.jpg
#   inflating: only_tomato/train/Tomato/42182.jpg
#   inflating: only_tomato/train/Tomato/39019.jpg
#   inflating: only_tomato/train/Tomato/39945.jpg
#   inflating: only_tomato/train/Tomato/39796.jpg
#   inflating: only_tomato/train/Tomato/21173.jpg
#   inflating: only_tomato/train/Tomato/44017.jpg
#   inflating: only_tomato/train/Tomato/37861.jpg
#   inflating: only_tomato/train/Tomato/38826.jpg
#   inflating: only_tomato/train/Tomato/38741.jpg
#   inflating: only_tomato/train/Tomato/43432.jpg
#   inflating: only_tomato/train/Tomato/38377.jpg
#   inflating: only_tomato/train/Tomato/42876.jpg
#   inflating: only_tomato/train/Tomato/43496.jpg
#   inflating: only_tomato/train/Tomato/39077.jpg
#   inflating: only_tomato/train/Tomato/38405.jpg
#   inflating: only_tomato/train/Tomato/41069.jpg
#   inflating: only_tomato/train/Tomato/42601.jpg
#   inflating: only_tomato/train/Tomato/40719.jpg
#   inflating: only_tomato/train/Tomato/41733.jpg
#   inflating: only_tomato/train/Tomato/39531.jpg
#   inflating: only_tomato/train/Tomato/42510.jpg
#    creating: only_tomato/val/
#    creating: only_tomato/val/Others/
#   inflating: only_tomato/val/Others/05165.jpg
#   inflating: only_tomato/val/Others/24056.jpg
#   inflating: only_tomato/val/Others/07436.jpg
#   inflating: only_tomato/val/Others/33807.jpg
#   inflating: only_tomato/val/Others/14578.jpg
#   inflating: only_tomato/val/Others/14680.jpg
#   inflating: only_tomato/val/Others/05543.jpg
#   inflating: only_tomato/val/Others/31976.jpg
#   inflating: only_tomato/val/Others/05299.jpg
#   inflating: only_tomato/val/Others/00505.jpg
#   inflating: only_tomato/val/Others/06285.jpg
#   inflating: only_tomato/val/Others/33960.jpg
#   inflating: only_tomato/val/Others/28339.jpg
#   inflating: only_tomato/val/Others/18632.jpg
#   inflating: only_tomato/val/Others/15198.jpg
#   inflating: only_tomato/val/Others/25414.jpg
#   inflating: only_tomato/val/Others/00216.jpg
#   inflating: only_tomato/val/Others/05329.jpg
#   inflating: only_tomato/val/Others/35076.jpg
#   inflating: only_tomato/val/Others/33729.jpg
#   inflating: only_tomato/val/Others/14804.jpg
#   inflating: only_tomato/val/Others/28889.jpg
#   inflating: only_tomato/val/Others/04190.jpg
#   inflating: only_tomato/val/Others/28555.jpg
#   inflating: only_tomato/val/Others/01751.jpg
#   inflating: only_tomato/val/Others/27719.jpg
#   inflating: only_tomato/val/Others/19191.jpg
#   inflating: only_tomato/val/Others/31893.jpg
#   inflating: only_tomato/val/Others/22571.jpg
#   inflating: only_tomato/val/Others/03438.jpg
#   inflating: only_tomato/val/Others/28964.jpg
#   inflating: only_tomato/val/Others/06063.jpg
#   inflating: only_tomato/val/Others/19014.jpg
#   inflating: only_tomato/val/Others/13517.jpg
#   inflating: only_tomato/val/Others/00553.jpg
#   inflating: only_tomato/val/Others/27757.jpg
#   inflating: only_tomato/test/Tomato/21407.jpg
#   inflating: only_tomato/test/Tomato/38710.jpg
#   inflating: only_tomato/test/Tomato/42589.jpg
#   inflating: only_tomato/test/Tomato/42288.jpg
#   inflating: only_tomato/test/Tomato/42016.jpg
#   inflating: only_tomato/test/Tomato/43111.jpg
#   inflating: only_tomato/test/Tomato/21341.jpg
#   inflating: only_tomato/test/Tomato/21412.jpg
#   inflating: only_tomato/test/Tomato/40326.jpg
#   inflating: only_tomato/test/Tomato/37741.jpg
#   inflating: only_tomato/test/Tomato/42699.jpg
#   inflating: only_tomato/test/Tomato/43059.jpg
#   inflating: only_tomato/test/Tomato/21430.jpg
#   inflating: only_tomato/test/Tomato/39335.jpg
#   inflating: only_tomato/test/Tomato/40138.jpg
#   inflating: only_tomato/test/Tomato/39058.jpg
#   inflating: only_tomato/test/Tomato/38687.jpg
#   inflating: only_tomato/test/Tomato/42117.jpg
#   inflating: only_tomato/test/Tomato/42836.jpg
#   inflating: only_tomato/test/Tomato/41447.jpg
#   inflating: only_tomato/test/Tomato/40028.jpg
#   inflating: only_tomato/test/Tomato/41795.jpg
#   inflating: only_tomato/test/Tomato/39819.jpg
#   inflating: only_tomato/test/Tomato/41102.jpg
#   inflating: only_tomato/test/Tomato/20854.jpg
#   inflating: only_tomato/test/Tomato/40986.jpg
#   inflating: only_tomato/test/Tomato/38790.jpg
#   inflating: only_tomato/test/Tomato/21431.jpg
#   inflating: only_tomato/test/Tomato/41211.jpg
#   inflating: only_tomato/test/Tomato/39293.jpg
#   inflating: only_tomato/test/Tomato/42065.jpg
#   inflating: only_tomato/test/Tomato/42109.jpg
#   inflating: only_tomato/test/Tomato/41266.jpg
#   inflating: only_tomato/test/Tomato/38812.jpg
#   inflating: only_tomato/test/Tomato/39532.jpg
#   inflating: only_tomato/test/Tomato/38063.jpg
#   inflating: only_tomato/test/Tomato/20984.jpg
#   inflating: only_tomato/test/Tomato/42686.jpg
#   inflating: only_tomato/test/Tomato/43811.jpg
#   inflating: only_tomato/test/Tomato/21345.jpg
#   inflating: only_tomato/test/Tomato/38112.jpg
#   inflating: only_tomato/test/Tomato/42784.jpg
#   inflating: only_tomato/test/Tomato/41671.jpg
#   inflating: only_tomato/test/Tomato/37889.jpg
#   inflating: only_tomato/test/Tomato/39665.jpg
#   inflating: only_tomato/test/Tomato/41868.jpg
#   inflating: only_tomato/test/Tomato/43956.jpg
#   inflating: only_tomato/test/Tomato/38990.jpg
#   inflating: only_tomato/test/Tomato/44219.jpg
#   inflating: only_tomato/test/Tomato/38536.jpg
#   inflating: only_tomato/test/Tomato/41731.jpg
#   inflating: only_tomato/test/Tomato/42644.jpg
#   inflating: only_tomato/test/Tomato/39061.jpg
#   inflating: only_tomato/test/Tomato/39074.jpg
#   inflating: only_tomato/test/Tomato/39655.jpg
#   inflating: only_tomato/test/Tomato/38228.jpg
#   inflating: only_tomato/test/Tomato/40582.jpg
#   inflating: only_tomato/test/Tomato/41229.jpg
#   inflating: only_tomato/test/Tomato/37738.jpg
#   inflating: only_tomato/test/Tomato/38116.jpg
#   inflating: only_tomato/test/Tomato/43750.jpg
#   inflating: only_tomato/test/Tomato/43825.jpg
#   inflating: only_tomato/test/Tomato/21381.jpg
#   inflating: only_tomato/test/Tomato/41913.jpg
#   inflating: only_tomato/test/Tomato/41323.jpg
#   inflating: only_tomato/test/Tomato/41452.jpg
#   inflating: only_tomato/test/Tomato/40742.jpg
#   inflating: only_tomato/test/Tomato/41537.jpg
#   inflating: only_tomato/test/Tomato/43879.jpg
#   inflating: only_tomato/test/Tomato/38103.jpg
#   inflating: only_tomato/test/Tomato/38075.jpg
#   inflating: only_tomato/test/Tomato/39062.jpg
#   inflating: only_tomato/test/Tomato/41271.jpg
#   inflating: only_tomato/test/Tomato/41974.jpg
#   inflating: only_tomato/test/Tomato/39601.jpg
#   inflating: only_tomato/test/Tomato/41972.jpg
#   inflating: only_tomato/test/Tomato/43030.jpg
#   inflating: only_tomato/test/Tomato/42981.jpg
#   inflating: only_tomato/test/Tomato/38448.jpg
#   inflating: only_tomato/test/Tomato/43995.jpg
#   inflating: only_tomato/test/Tomato/39297.jpg
#   inflating: only_tomato/test/Tomato/42106.jpg
#   inflating: only_tomato/test/Tomato/39957.jpg
#   inflating: only_tomato/test/Tomato/39548.jpg
#   inflating: only_tomato/test/Tomato/42407.jpg
#   inflating: only_tomato/test/Tomato/37836.jpg
#   inflating: only_tomato/test/Tomato/40489.jpg
#   inflating: only_tomato/test/Tomato/21151.jpg
#   inflating: only_tomato/test/Tomato/37803.jpg
#   inflating: only_tomato/test/Tomato/39453.jpg
#   inflating: only_tomato/test/Tomato/21435.jpg
#   inflating: only_tomato/test/Tomato/43591.jpg
#   inflating: only_tomato/test/Tomato/37837.jpg
#   inflating: only_tomato/test/Tomato/20908.jpg
#   inflating: only_tomato/test/Tomato/39364.jpg
#   inflating: only_tomato/test/Tomato/43154.jpg
#   inflating: only_tomato/test/Tomato/39465.jpg
#   inflating: only_tomato/test/Tomato/42820.jpg
#   inflating: only_tomato/test/Tomato/43153.jpg
#   inflating: only_tomato/test/Tomato/21048.jpg
#   inflating: only_tomato/test/Tomato/40568.jpg
#   inflating: only_tomato/test/Tomato/37769.jpg
#   inflating: only_tomato/test/Tomato/39409.jpg
#   inflating: only_tomato/test/Tomato/39649.jpg
#   inflating: only_tomato/test/Tomato/38342.jpg
#   inflating: only_tomato/test/Tomato/41756.jpg
#   inflating: only_tomato/test/Tomato/42444.jpg
#   inflating: only_tomato/test/Tomato/41614.jpg
#   inflating: only_tomato/test/Tomato/40934.jpg
#   inflating: only_tomato/test/Tomato/44208.jpg
#   inflating: only_tomato/test/Tomato/41189.jpg
#   inflating: only_tomato/test/Tomato/40302.jpg
#   inflating: only_tomato/test/Tomato/39167.jpg
#   inflating: only_tomato/test/Tomato/42671.jpg
#   inflating: only_tomato/test/Tomato/39271.jpg
#   inflating: only_tomato/test/Tomato/41448.jpg
#   inflating: only_tomato/test/Tomato/43341.jpg
#   inflating: only_tomato/test/Tomato/42552.jpg
#   inflating: only_tomato/test/Tomato/39818.jpg
#   inflating: only_tomato/test/Tomato/38796.jpg
#   inflating: only_tomato/test/Tomato/42776.jpg
#   inflating: only_tomato/test/Tomato/42000.jpg
#   inflating: only_tomato/test/Tomato/43885.jpg
#   inflating: only_tomato/test/Tomato/38412.jpg
#   inflating: only_tomato/test/Tomato/38386.jpg
#   inflating: only_tomato/test/Tomato/42604.jpg
#   inflating: only_tomato/test/Tomato/37819.jpg
#   inflating: only_tomato/test/Tomato/42112.jpg
#   inflating: only_tomato/test/Tomato/37990.jpg
#   inflating: only_tomato/test/Tomato/44178.jpg
#   inflating: only_tomato/test/Tomato/42950.jpg
#   inflating: only_tomato/test/Tomato/39579.jpg
#   inflating: only_tomato/test/Tomato/21421.jpg
#   inflating: only_tomato/test/Tomato/39566.jpg
#   inflating: only_tomato/test/Tomato/40259.jpg
#   inflating: only_tomato/test/Tomato/40831.jpg
#   inflating: only_tomato/test/Tomato/38253.jpg
#   inflating: only_tomato/test/Tomato/21031.jpg
#   inflating: only_tomato/test/Tomato/42137.jpg
#   inflating: only_tomato/test/Tomato/40427.jpg
#   inflating: only_tomato/test/Tomato/43258.jpg
#   inflating: only_tomato/test/Tomato/20840.jpg
#   inflating: only_tomato/test/Tomato/42581.jpg
#   inflating: only_tomato/test/Tomato/42672.jpg
#   inflating: only_tomato/test/Tomato/38757.jpg
#   inflating: only_tomato/test/Tomato/40939.jpg
#   inflating: only_tomato/test/Tomato/44082.jpg
#   inflating: only_tomato/test/Tomato/39148.jpg
#   inflating: only_tomato/test/Tomato/43362.jpg
#   inflating: only_tomato/test/Tomato/44049.jpg
#   inflating: only_tomato/test/Tomato/43667.jpg
#   inflating: only_tomato/test/Tomato/40154.jpg
#   inflating: only_tomato/test/Tomato/43530.jpg
#   inflating: only_tomato/test/Tomato/38200.jpg
#   inflating: only_tomato/test/Tomato/42333.jpg
#   inflating: only_tomato/test/Tomato/38941.jpg
#   inflating: only_tomato/test/Tomato/42262.jpg
#   inflating: only_tomato/test/Tomato/39799.jpg
#   inflating: only_tomato/test/Tomato/20868.jpg
#   inflating: only_tomato/test/Tomato/41780.jpg
#   inflating: only_tomato/test/Tomato/38716.jpg
#   inflating: only_tomato/test/Tomato/41582.jpg
#   inflating: only_tomato/test/Tomato/40108.jpg
#   inflating: only_tomato/test/Tomato/38250.jpg
#   inflating: only_tomato/test/Tomato/40590.jpg
#   inflating: only_tomato/test/Tomato/43689.jpg
#   inflating: only_tomato/test/Tomato/39835.jpg
#   inflating: only_tomato/test/Tomato/42650.jpg
#   inflating: only_tomato/test/Tomato/38280.jpg
#   inflating: only_tomato/test/Tomato/20952.jpg
#   inflating: only_tomato/test/Tomato/42814.jpg
#   inflating: only_tomato/test/Tomato/39680.jpg
#   inflating: only_tomato/test/Tomato/42568.jpg
#   inflating: only_tomato/test/Tomato/41923.jpg
#   inflating: only_tomato/test/Tomato/43229.jpg
#   inflating: only_tomato/test/Tomato/41011.jpg
#   inflating: only_tomato/test/Tomato/41044.jpg
#   inflating: only_tomato/test/Tomato/37765.jpg
#   inflating: only_tomato/test/Tomato/43234.jpg
#   inflating: only_tomato/test/Tomato/41440.jpg
#   inflating: only_tomato/test/Tomato/38737.jpg
#   inflating: only_tomato/test/Tomato/43552.jpg
#   inflating: only_tomato/test/Tomato/38667.jpg
#   inflating: only_tomato/test/Tomato/38231.jpg
#   inflating: only_tomato/test/Tomato/21309.jpg
#   inflating: only_tomato/test/Tomato/38040.jpg
#   inflating: only_tomato/test/Tomato/42188.jpg
#   inflating: only_tomato/test/Tomato/42351.jpg
#   inflating: only_tomato/test/Tomato/38518.jpg
#   inflating: only_tomato/test/Tomato/39351.jpg
#   inflating: only_tomato/test/Tomato/40818.jpg
#   inflating: only_tomato/test/Tomato/41193.jpg
#   inflating: only_tomato/test/Tomato/43104.jpg
#   inflating: only_tomato/test/Tomato/41508.jpg
#   inflating: only_tomato/test/Tomato/43115.jpg
#   inflating: only_tomato/test/Tomato/39793.jpg
#   inflating: only_tomato/test/Tomato/42669.jpg
#   inflating: only_tomato/test/Tomato/42890.jpg
#   inflating: only_tomato/test/Tomato/39634.jpg
#   inflating: only_tomato/test/Tomato/44226.jpg
#   inflating: only_tomato/test/Tomato/39816.jpg
#   inflating: only_tomato/test/Tomato/38566.jpg
#   inflating: only_tomato/test/Tomato/41829.jpg
#   inflating: only_tomato/test/Tomato/43713.jpg
#   inflating: only_tomato/test/Tomato/41155.jpg
#   inflating: only_tomato/test/Tomato/42247.jpg
#   inflating: only_tomato/test/Tomato/43845.jpg
#   inflating: only_tomato/test/Tomato/39279.jpg
#   inflating: only_tomato/test/Tomato/40338.jpg
#   inflating: only_tomato/test/Tomato/42949.jpg
#   inflating: only_tomato/test/Tomato/39263.jpg
#   inflating: only_tomato/test/Tomato/37790.jpg
#   inflating: only_tomato/test/Tomato/39846.jpg
#   inflating: only_tomato/test/Tomato/41214.jpg
#   inflating: only_tomato/test/Tomato/40346.jpg
#   inflating: only_tomato/test/Tomato/21156.jpg
#   inflating: only_tomato/test/Tomato/39454.jpg
#   inflating: only_tomato/test/Tomato/21400.jpg
#   inflating: only_tomato/test/Tomato/40428.jpg
#   inflating: only_tomato/test/Tomato/39355.jpg
#   inflating: only_tomato/test/Tomato/42847.jpg
#   inflating: only_tomato/test/Tomato/43676.jpg
#   inflating: only_tomato/test/Tomato/39868.jpg
#   inflating: only_tomato/test/Tomato/40991.jpg
#   inflating: only_tomato/test/Tomato/41865.jpg
#   inflating: only_tomato/test/Tomato/38779.jpg
#   inflating: only_tomato/test/Tomato/39619.jpg
#   inflating: only_tomato/test/Tomato/42618.jpg
#   inflating: only_tomato/test/Tomato/38865.jpg
#   inflating: only_tomato/test/Tomato/43627.jpg
#   inflating: only_tomato/test/Tomato/43364.jpg
#   inflating: only_tomato/test/Tomato/37840.jpg
#   inflating: only_tomato/test/Tomato/43769.jpg
#   inflating: only_tomato/test/Tomato/44124.jpg
#   inflating: only_tomato/test/Tomato/39838.jpg
#   inflating: only_tomato/test/Tomato/43990.jpg
#   inflating: only_tomato/test/Tomato/39249.jpg
#   inflating: only_tomato/test/Tomato/40752.jpg
#   inflating: only_tomato/test/Tomato/40901.jpg
#   inflating: only_tomato/test/Tomato/38769.jpg
#   inflating: only_tomato/test/Tomato/40849.jpg
#   inflating: only_tomato/test/Tomato/43635.jpg
#   inflating: only_tomato/test/Tomato/41778.jpg
#   inflating: only_tomato/test/Tomato/39953.jpg
#   inflating: only_tomato/test/Tomato/40996.jpg
#   inflating: only_tomato/test/Tomato/38141.jpg
#   inflating: only_tomato/test/Tomato/39495.jpg
#   inflating: only_tomato/test/Tomato/37934.jpg
#   inflating: only_tomato/test/Tomato/40072.jpg
#   inflating: only_tomato/test/Tomato/39440.jpg
#   inflating: only_tomato/test/Tomato/43900.jpg
#   inflating: only_tomato/test/Tomato/21295.jpg
#   inflating: only_tomato/test/Tomato/37823.jpg
#   inflating: only_tomato/test/Tomato/39083.jpg
#   inflating: only_tomato/test/Tomato/43041.jpg
#   inflating: only_tomato/test/Tomato/40815.jpg
#   inflating: only_tomato/test/Tomato/43461.jpg
#   inflating: only_tomato/test/Tomato/43562.jpg
#   inflating: only_tomato/test/Tomato/40105.jpg
#   inflating: only_tomato/test/Tomato/42800.jpg
#   inflating: only_tomato/test/Tomato/37924.jpg
#   inflating: only_tomato/test/Tomato/40981.jpg
#   inflating: only_tomato/test/Tomato/38378.jpg
#   inflating: only_tomato/test/Tomato/42643.jpg
#   inflating: only_tomato/test/Tomato/41836.jpg
#   inflating: only_tomato/test/Tomato/21268.jpg
#   inflating: only_tomato/test/Tomato/39812.jpg
#   inflating: only_tomato/test/Tomato/43308.jpg
#   inflating: only_tomato/test/Tomato/40634.jpg
#   inflating: only_tomato/test/Tomato/40788.jpg
#   inflating: only_tomato/test/Tomato/38101.jpg
#   inflating: only_tomato/test/Tomato/40995.jpg
#   inflating: only_tomato/test/Tomato/38058.jpg
#   inflating: only_tomato/test/Tomato/38153.jpg
#   inflating: only_tomato/test/Tomato/40552.jpg
#   inflating: only_tomato/test/Tomato/39309.jpg
#   inflating: only_tomato/test/Tomato/38693.jpg
#   inflating: only_tomato/test/Tomato/39952.jpg
#   inflating: only_tomato/test/Tomato/40591.jpg
#   inflating: only_tomato/test/Tomato/41444.jpg
#   inflating: only_tomato/test/Tomato/38733.jpg
#   inflating: only_tomato/test/Tomato/20903.jpg
#   inflating: only_tomato/test/Tomato/39954.jpg
#   inflating: only_tomato/test/Tomato/43161.jpg
#   inflating: only_tomato/test/Tomato/41736.jpg
#   inflating: only_tomato/test/Tomato/39366.jpg
#   inflating: only_tomato/test/Tomato/41413.jpg
#   inflating: only_tomato/test/Tomato/42727.jpg
#   inflating: only_tomato/test/Tomato/43791.jpg
#   inflating: only_tomato/test/Tomato/39147.jpg
#   inflating: only_tomato/test/Tomato/42888.jpg
#   inflating: only_tomato/test/Tomato/21102.jpg
#   inflating: only_tomato/test/Tomato/43294.jpg
#   inflating: only_tomato/test/Tomato/42312.jpg
#   inflating: only_tomato/test/Tomato/39491.jpg
#   inflating: only_tomato/test/Tomato/39344.jpg
#   inflating: only_tomato/test/Tomato/38066.jpg
#   inflating: only_tomato/test/Tomato/21135.jpg
#   inflating: only_tomato/test/Tomato/21154.jpg
#   inflating: only_tomato/test/Tomato/41437.jpg
#   inflating: only_tomato/test/Tomato/43172.jpg
#   inflating: only_tomato/test/Tomato/38003.jpg
#   inflating: only_tomato/test/Tomato/42730.jpg
#   inflating: only_tomato/test/Tomato/44058.jpg
#   inflating: only_tomato/test/Tomato/38158.jpg
#   inflating: only_tomato/test/Tomato/38528.jpg
#   inflating: only_tomato/test/Tomato/39396.jpg
#   inflating: only_tomato/test/Tomato/39620.jpg
#   inflating: only_tomato/test/Tomato/39920.jpg
#   inflating: only_tomato/test/Tomato/21088.jpg
#   inflating: only_tomato/test/Tomato/38249.jpg
#   inflating: only_tomato/test/Tomato/43671.jpg

# %% [markdown]
# #Imports

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from PIL import Image

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# #Loading data & folder Exploring

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
dataset_dir = 'only_tomato'

training_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'val')
test_dir = os.path.join(dataset_dir, 'test')

# %%
# Plot example images from dataset
labels = ['Others','Tomato']

num_row = len(labels)//2
num_col = len(labels)//num_row
fig, axes = plt.subplots(num_row, num_col, figsize=(10, 10))
for i in range(len(labels)):
  if i < len(labels):
    class_imgs = next(os.walk('{}/train/{}/'.format(dataset_dir, labels[i])))[2]
    class_img = class_imgs[0]
    img = Image.open('{}/train/{}/{}'.format(dataset_dir, labels[i], class_img))
    ax = axes[i]
    ax.imshow(np.array(img))
    ax.set_title('{}'.format(labels[i]))


plt.tight_layout()
plt.show()

# %% [markdown]
# #Data Generator

# %% [markdown]
# Import:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Create an instance of ImageDataGenerator with NO Data Augmentation
noaug_train_data_gen = ImageDataGenerator(rescale=1/255.)
valid_data_gen = ImageDataGenerator(rescale=1/255.)
test_data_gen = ImageDataGenerator(rescale=1/255.)

# Obtain a data generator with the 'ImageDataGenerator.flow_from_directory' method
# Increased batch size
noaug_train_gen = noaug_train_data_gen.flow_from_directory(directory=training_dir,
                                               target_size=(256, 256),
                                               color_mode='rgb',
                                               classes=None,
                                               batch_size=120,
                                               shuffle=True,
                                               seed=seed)

valid_gen = valid_data_gen.flow_from_directory(directory=validation_dir,
                                               target_size=(256, 256),
                                               color_mode='rgb',
                                               classes=None,
                                               batch_size=120,
                                               shuffle=False,
                                               seed=seed)

test_gen = test_data_gen.flow_from_directory(directory=test_dir,
                                               target_size=(256, 256),
                                               color_mode='rgb',
                                               classes=None,
                                               batch_size=120,
                                               shuffle=False,
                                               seed=seed)
# Out:
# Found 13295 images belonging to 2 classes.
# Found 2658 images belonging to 2 classes.
# Found 1775 images belonging to 2 classes.

# %% [markdown]
# #Characteristics

# %%
# We set the input shape and the numbero of epochs
input_shape = (256, 256, 3)
epochs = 200

# %% [markdown]
# #Declaring Network

# %%
# We use the same model seen during the exercise session
def build_model(input_shape):

    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    conv1 = tfkl.Conv2D(
        filters=16,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(input_layer)
    pool1 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv1)

    conv2 = tfkl.Conv2D(
        filters=32,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool1)
    pool2 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv2)

    conv3 = tfkl.Conv2D(
        filters=64,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool2)
    pool3 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv3)

    conv4 = tfkl.Conv2D(
        filters=128,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool3)
    pool4 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv4)

    conv5 = tfkl.Conv2D(
        filters=256,
        kernel_size=(3, 3),
        strides = (1, 1),
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.GlorotUniform(seed)
    )(pool4)
    pool5 = tfkl.MaxPooling2D(
        pool_size = (2, 2)
    )(conv5)

    flattening_layer = tfkl.Flatten(name='Flatten')(pool5)
    flattening_layer = tfkl.Dropout(0.3, seed=seed)(flattening_layer)
    classifier_layer = tfkl.Dense(units=512, name='Classifier', kernel_initializer=tfk.initializers.GlorotUniform(seed), activation='relu')(flattening_layer)
    classifier_layer = tfkl.Dropout(0.3, seed=seed)(classifier_layer)
    output_layer = tfkl.Dense(units=2, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='Output')(classifier_layer)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %% [markdown]
# #Building Model

# %%
# Build model
model = build_model(input_shape)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  Flatten (Flatten)           (None, 16384)             0
#
#  dropout (Dropout)           (None, 16384)             0
#
#  Classifier (Dense)          (None, 512)               8389120
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  Output (Dense)              (None, 2)                 1026
#
# =================================================================
# Total params: 8,782,754
# Trainable params: 8,782,754
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Training the model

# %%
# Create folders and callbacks and fit
# Patience set to 8
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
# Train the model
history = model.fit(
    x = noaug_train_gen,
    epochs = epochs,
    validation_data = valid_gen,
    callbacks = [early_stopping],
).history

# %% [markdown]
# #Saving the model

# %%
# Save best epoch model
model.save("First_Run")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# INFO:tensorflow:Assets written to: First_Run/assets
# INFO:tensorflow:Assets written to: First_Run/assets

# %% [markdown]
# #Plot training error and validation error

# %%
plt.figure(figsize=(15,5))
plt.plot(history['loss'], label='Training', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation', alpha=.8, color='#4D61E2')
plt.ylim(0, 1)
plt.title('Loss')
plt.legend(loc='upper right')
plt.grid(alpha=.3)
plt.show()

# %% [markdown]
# # Show predictions

# %%
model = tfk.models.load_model("First_Run")

# %%
test_gen = test_data_gen.flow_from_directory(directory=test_dir,
                                               target_size=(256, 256),
                                               color_mode='rgb',
                                               classes=None,
                                               batch_size=1,
                                               shuffle=True,
                                               seed=seed)
# Out:
# Found 1775 images belonging to 2 classes.

# %%
model_metrics = model.evaluate(test_gen, return_dict=True)
print(model_metrics)

# %%
batch = next(test_gen)
target = batch[1]
batch = batch[0]

# Get first image
image = batch[0] # batch size = 120
print(batch.shape)
target_label = labels[np.argmax(target[0])]

y = np.expand_dims(image, axis=0)
print(y.shape)
predictions = model.predict(y)
predictions.shape

fig, (ax1, ax2) = plt.subplots(1,2)
fig.set_size_inches(18,5)
ax1.imshow(image)
ax1.set_title('True label: '+target_label)
ax2.barh(labels, predictions[0], color=plt.get_cmap('Paired').colors)
ax2.set_title('Predicted label: '+labels[np.argmax(predictions[0])])
ax2.grid(alpha=.3)
plt.show()
# Out:
# (1, 256, 256, 3)
# (1, 256, 256, 3)
